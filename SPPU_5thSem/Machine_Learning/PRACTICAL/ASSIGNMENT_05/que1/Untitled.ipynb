# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cities_r2.csv')

# %%
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
x=df.iloc[:,13::2]

# %%
x
# Out:
#      sex_ratio  effective_literacy_rate_total  effective_literacy_rate_female  \
# 0          890                          79.86                           73.59
# 1          928                          91.99                           89.00
# 2          982                          80.51                           72.73
# 3          902                          83.46                           76.23
# 4         1013                          68.38                           60.33
# ..         ...                            ...                             ...
# 488       1039                          81.85                           75.80
# 489        998                          84.16                           76.79
# 490        982                          94.05                           90.88
# 491        877                          85.91                           81.71
# 492        988                          91.81                           88.17
#
# ...

# %%
# Out:
#       name_of_city  state_code  state_name  dist_code  population_total  \
# 0          Abohar            3          22          9            145238
# 1        Achalpur           27          14          7            112293
# 2        Adilabad           28           1          1            117388
# 3       Adityapur           20          10         24            173988
# 4           Adoni           28           1         21            166537
# ..             ...         ...         ...        ...               ...
# 488  Vizianagaram           28           1         12            227533
# 489      Warangal           28           1          9            620116
# 490        Wardha           27          14          8            105543
# 491   Yamunanagar            6           7          3            216628
# 492      Yavatmal           27          14         14            116714
#
#      population_male  population_female  0-6_population_total  \
# ...

# %%
y=df[['effective_literacy_rate_total']]
x
y
# Out:
#      effective_literacy_rate_total
# 0                            79.86
# 1                            91.99
# 2                            80.51
# 3                            83.46
# 4                            68.38
# ..                             ...
# 488                          81.85
# 489                          84.16
# 490                          94.05
# 491                          85.91
# 492                          91.81
#
# [493 rows x 1 columns]

# %%
plt.title('Unclustered')
plt.xlabel('sex_ratio')
plt.ylabel('effective_literacy_rate_total')
plt.scatter(x['sex_ratio'],x['effective_literacy_rate_total'],marker='.',color='b')

# %%
from sklearn.cluster import KMeans,AgglomerativeClustering

# %%
# Out:
# KMeans(n_clusters=5)

# %%
# Out:
# C:\Users\sanik\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\sanik\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# array([2, 1, 0, 1, 3, 3, 2, 1, 0, 3, 0, 0, 0, 3, 3, 2, 2, 2, 1, 1, 1, 0,
#        1, 3, 0, 1, 2, 1, 1, 3, 0, 2, 1, 0, 1, 1, 0, 1, 1, 2, 0, 2, 0, 2,
#        0, 0, 2, 2, 1, 3, 2, 0, 1, 0, 1, 0, 0, 2, 0, 2, 1, 2, 0, 0, 0, 1,
#        1, 2, 0, 2, 0, 3, 1, 2, 0, 0, 3, 1, 2, 2, 2, 0, 2, 1, 0, 1, 3, 2,
#        4, 4, 2, 1, 2, 2, 0, 1, 0, 0, 1, 0, 1, 0, 2, 0, 1, 1, 1, 1, 1, 2,
#        0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 0, 3, 3, 3, 1, 3, 0, 3, 3, 3, 0,
# ...

# %%
x
# Out:
#      sex_ratio  effective_literacy_rate_total
# 0          890                          79.86
# 1          928                          91.99
# 2          982                          80.51
# 3          902                          83.46
# 4         1013                          68.38
# ..         ...                            ...
# 488       1039                          81.85
# 489        998                          84.16
# 490        982                          94.05
# 491        877                          85.91
# 492        988                          91.81
#
# [493 rows x 2 columns]

# %%
elblist=[]

# %%
silh=[]
for i in range(1,16):
    km=KMeans(n_clusters=i,n_init=100)
    km.fit_predict(x)
    silh.append(km.inertia_)
silh

# %%
silh
# Out:
# [1553437.620489655,
#  529161.5115888764,
#  317624.7518522494,
#  218901.73321411066,
#  153766.82426282897,
#  113679.20700292866,
#  83292.44388049933,
#  69679.28548501647,
#  57607.10841814753,
#  48292.1859420843,
#  42844.458826969894,
#  38843.72343162876,
#  35108.25362026296,
#  32138.213668564073,
#  30065.493423488606]
