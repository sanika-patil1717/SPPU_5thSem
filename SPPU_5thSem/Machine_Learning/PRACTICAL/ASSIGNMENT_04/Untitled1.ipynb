# %%
import pandas as pd

# %%
df=pd.read_csv('pima-indians-diabetes.csv',header=None)

# %%
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=df.iloc[:,:8]
y=df.iloc[:,8:9]

# %%
x
# Out:
#       0    1   2   3    4     5      6   7
# 0     6  148  72  35    0  33.6  0.627  50
# 1     1   85  66  29    0  26.6  0.351  31
# 2     8  183  64   0    0  23.3  0.672  32
# 3     1   89  66  23   94  28.1  0.167  21
# 4     0  137  40  35  168  43.1  2.288  33
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 763  10  101  76  48  180  32.9  0.171  63
# 764   2  122  70  27    0  36.8  0.340  27
# 765   5  121  72  23  112  26.2  0.245  30
# 766   1  126  60   0    0  30.1  0.349  47
# 767   1   93  70  31    0  30.4  0.315  23
#
# [768 rows x 8 columns]

# %%
y
# Out:
#      8
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# ..  ..
# 763  0
# 764  0
# 765  0
# 766  1
# 767  0
#
# [768 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.25)

# %%
x_train.shape
# Out:
# (576, 8)

# %%
x_test.shape
# Out:
# (192, 8)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gua=GaussianNB()

# %%
gua.fit(x_train,y_train)
# Out:
# C:\Users\sanik\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_pred=gua.predict(x_test)

# %%
from sklearn.metrics import classification_report,ConfusionMatricsDisplay,accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.metrics import classification_report,ConfusionMatricsDisplay,accuracy_score
#
# ImportError: cannot import name 'ConfusionMatricsDisplay' from 'sklearn.metrics' (C:\Users\sanik\anaconda3\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
from sklearn.metrics import classification_report,ConfusionMatrixDisplay,accuracy_score

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.765625

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       130
#            1       0.67      0.53      0.59        62
#
#     accuracy                           0.77       192
#    macro avg       0.74      0.70      0.71       192
# weighted avg       0.76      0.77      0.76       192

# %%
ConfusionMatrixDIsplay(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ConfusionMatrixDIsplay(y_test,y_pred)
#
# NameError: name 'ConfusionMatrixDIsplay' is not defined

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
#decision tree classification

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1=dtree.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred1))
# Out:
# 0.734375

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       130
#            1       0.58      0.65      0.61        62
#
#     accuracy                           0.73       192
#    macro avg       0.70      0.71      0.70       192
# weighted avg       0.74      0.73      0.74       192

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dtree,fontsize=7,rounded=True,filled=True)
# Out:
# [Text(0.5608821525885559, 0.9705882352941176, 'x[1] <= 144.5\ngini = 0.459\nsamples = 576\nvalue = [370, 206]'),
#  Text(0.2443801089918256, 0.9117647058823529, 'x[7] <= 28.5\ngini = 0.372\nsamples = 445\nvalue = [335, 110]'),
#  Text(0.09673024523160763, 0.8529411764705882, 'x[5] <= 30.45\ngini = 0.21\nsamples = 235\nvalue = [207, 28]'),
#  Text(0.0326975476839237, 0.7941176470588235, 'x[0] <= 7.0\ngini = 0.035\nsamples = 113\nvalue = [111, 2]'),
#  Text(0.021798365122615803, 0.7352941176470589, 'x[6] <= 0.672\ngini = 0.018\nsamples = 112\nvalue = [111, 1]'),
#  Text(0.010899182561307902, 0.6764705882352942, 'gini = 0.0\nsamples = 99\nvalue = [99, 0]'),
#  Text(0.0326975476839237, 0.6764705882352942, 'x[3] <= 13.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.021798365122615803, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.043596730245231606, 0.6176470588235294, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
# ...

# %%
import matplotlib.pyplot as plt

# %%
plot_tree(dtree,filled=True,rounded=True,fontsize=6)
plt.show()
