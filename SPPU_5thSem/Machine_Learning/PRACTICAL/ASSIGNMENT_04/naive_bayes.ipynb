# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('NaiveBayes.csv')

# %%
df
# Out:
#      Age  Salary  Purchased
# 0     19   19000          0
# 1     35   20000          0
# 2     26   43000          0
# 3     27   57000          0
# 4     19   76000          0
# ..   ...     ...        ...
# 395   46   41000          1
# 396   51   23000          1
# 397   50   20000          1
# 398   36   33000          0
# 399   49   36000          1
#
# [400 rows x 3 columns]

# %%
df.shape
# Out:
# (400, 3)

# %%
df.head()
# Out:
#    Age  Salary  Purchased
# 0   19   19000          0
# 1   35   20000          0
# 2   26   43000          0
# 3   27   57000          0
# 4   19   76000          0

# %%
from sklearn.model_preparation import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.model_preparation import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn.model_preparation'

# %%
#scatter plot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(14,9))
sns.scatterplot(x=df['Age'],y=df['Salary'],hue=df['Purchased'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x=df[['Age','Salary']]
y=df[['Purchased']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.25)

# %%
x_train.shape
# Out:
# (300, 2)

# %%
x_test.shape
# Out:
# (100, 2)

# %%
y_train
# Out:
#      Purchased
# 250          0
# 63           1
# 312          0
# 159          1
# 283          1
# ..         ...
# 323          1
# 192          0
# 117          0
# 47           0
# 172          0
#
# [300 rows x 1 columns]

# %%
from sklearn.naive_bayes import GuassianNB
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from sklearn.naive_bayes import GuassianNB
#
# ImportError: cannot import name 'GuassianNB' from 'sklearn.naive_bayes' (C:\Users\sanik\anaconda3\Lib\site-packages\sklearn\naive_bayes.py)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gua=GaussianNB()

# %%
gua.fit(x_train,y_train)
# Out:
# C:\Users\sanik\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_pred=gua.predict(x_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 ConfusionMatrixDisplay(y_test,y_pred)
#
# TypeError: ConfusionMatrixDisplay.__init__() takes 2 positional arguments but 3 were given

# %%
ConfusionMatrixDisplay.from_prediction(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 ConfusionMatrixDisplay.from_prediction(y_test,y_pred)
#
# AttributeError: type object 'ConfusionMatrixDisplay' has no attribute 'from_prediction'

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93        68
#            1       0.89      0.78      0.83        32
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.87      0.88       100
# weighted avg       0.90      0.90      0.90       100
